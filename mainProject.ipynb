# %% [markdown]
# <a href="https://colab.research.google.com/github/messaf27/GB_HomeWorks/blob/master/mainProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
penguins = sns.load_dataset("penguins")

# %%
print(penguins)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  high_bill_deph  bill_high_deph  high_deph  \
# ...

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
penguins['high_deph'] = penguins['bill_length_mm'] > 42
penguins['middle_deph'] = (penguins['bill_length_mm'] > 35) & (penguins['bill_length_mm'] > 35)
penguins['low_deph'] = penguins['bill_length_mm'] < 35
penguins.columns
print(penguins[['high_deph', 'middle_deph','low_deph']])
# Out:
#      high_deph  middle_deph  low_deph
# 0        False         True     False
# 1        False         True     False
# 2        False         True     False
# 3        False        False     False
# 4        False         True     False
# ..         ...          ...       ...
# 339      False        False     False
# 340       True         True     False
# 341       True         True     False
# 342       True         True     False
# 343       True         True     False
#
# [344 rows x 3 columns]

# %%
penguins[penguins['high_deph'] == True]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 17   Adelie  Torgersen            42.5           20.7              197.0
# 19   Adelie  Torgersen            46.0           21.5              194.0
# 37   Adelie      Dream            42.2           18.5              180.0
# 43   Adelie      Dream            44.1           19.7              196.0
# 49   Adelie      Dream            42.3           21.2              191.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  high_bill_deph  bill_high_deph  high_deph  \
# ...

# %%
penguins[penguins['middle_deph'] == True]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  high_bill_deph  bill_high_deph  high_deph  \
# ...

# %%
penguins[penguins['low_deph'] == True]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# 18   Adelie  Torgersen            34.4           18.4              184.0
# 54   Adelie     Biscoe            34.5           18.1              187.0
# 70   Adelie  Torgersen            33.5           19.0              190.0
# 80   Adelie  Torgersen            34.6           17.2              189.0
# 92   Adelie      Dream            34.0           17.1              185.0
# 98   Adelie      Dream            33.1           16.1              178.0
# 142  Adelie      Dream            32.1           15.5              188.0
#
#      body_mass_g     sex  high_bill_deph  bill_high_deph  high_deph  \
# 8         3475.0     NaN           False           False      False
# 14        4400.0    Male           False           False      False
# ...
